# %% [markdown]
# # 01 Data Cleaning
#
# This notebook validates the raw Maryland county sample file, standardizes county identifiers, creates feature indices, and writes the SQLite database plus dashboard-ready files.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parents[0] if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

from src.data_pipeline import load_raw_data, clean_data, add_feature_indices, run_pipeline

raw = load_raw_data()
raw.head()

# %%
raw.info()

# %%
cleaned = clean_data(raw)
cleaned[['county_fips', 'county_name', 'population', 'poverty_pct', 'uninsured_pct']].head()

# %%
featured = add_feature_indices(cleaned)
featured[['county_name', 'provider_gap_index', 'socioeconomic_need_index', 'chronic_burden_index', 'hospital_quality_gap_index', 'access_risk_score', 'access_risk_tier']].sort_values('access_risk_score', ascending=False).head(10)

# %%
featured = run_pipeline()
print(f'Wrote processed files for {len(featured)} counties.')
